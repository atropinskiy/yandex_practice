# %%
import pandas as pd
import phik
import seaborn as sns
columns = ['1','2','3']
data = [[2, 3, 4],[3,1,2]]
df = pd.DataFrame(columns = columns, data = data)
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >
